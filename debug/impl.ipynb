# %%
import equation_database_grabber as edbg

# %%
edbg.grab('test3.png')
# Out:
# original image:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=757x90>
# IMG -> TEX:
# $\displaystyle S_{b1}\frac{\alpha_{s}}{\epsilon\pi}\left[-\frac{1}{2}\log\left(\frac{(v_{b}\cdot v_{1})^{2}s}{2m_{1}^{2}}\right)+L_{1}+\frac{1}{2}\log\left(\frac{(v_{b}\cdot n)^{2}}{|n|^{2}}\right)-1\right]$
# TEX -> SYM:
# S_{b1}*alpha_s*(L_1 - 1*1*log((s*(v_1*v_b)**2)/((2*m_1**2)), 10)/2 + 1*log((n*v_b)**2/(Abs(n)**2), 10)/2 - 1)/((pi*epsilon))
# SYM -> CPP:
# S_{b1}*alpha_s*(L_1 - 1*log((s*pow(v_1*v_b, 2))/((2*pow(m_1, 2))), 10)/2 + 1*log(pow(n*v_b, 2)/pow(fabs(n), 2), 10)/2 - 1)/((M_PI*epsilon))
#
# SYM -> Mathematica:
# No mathematica representation found
# <lambda>() takes 1 positional argument but 2 were given
#
# SYM -> Python:
# S_b1*alpha_s*(L_1 - 1*math.log((s*(v_1*v_b)**2)/((2*m_1**2)), 10)/2 + 1*math.log((n*v_b)**2/abs(n)**2, 10)/2 - 1)/((math.pi*epsilon))
#
# SYM -> Fortran:
#       parameter (pi = 3.1415926535897932d0)
# ...

# %%
a=_

# %%
print(a[1])
# Out:
# S_{b1}\frac{\alpha_{s}}{\epsilon\pi}\left[-\frac{1}{2}\log\left(\frac{(v_{b}\cdot v_{1})^{2}s}{2m_{1}^{2}}\right)+L_{1}+\frac{1}{2}\log\left(\frac{(v_{b}\cdot n)^{2}}{|n|^{2}}\right)-1\right]
