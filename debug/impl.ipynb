# %%
import equation_database_grabber as edbg

# %%
edbg.grab('test2.png')
# Out:
# original image:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=774x95>
# IMG -> TEX:
# $\displaystyle S_{a b}\frac{\alpha_{s}}{\epsilon\pi}\left[-\log\left(\frac{v_{a}\cdot v_{b}}{2}\right)+\frac{1}{2}\log\left(\frac{(v_{a}\cdot n)^{2}}{|n|^{2}}\frac{(v_{b}\cdot n)^{2}}{|n|^{2}}\right)+i\pi-1\right]$
# TEX -> SYM:
# S_{ab}*alpha_s*(pi*i - log((v_a*v_b)/2, 10) + 1*log((n*v_a)**2*(n*v_b)**2/(((Abs(n)**2))*Abs(n)**2), 10)/2 - 1)/((pi*epsilon))
# SYM -> CPP:
# S_{ab}*alpha_s*(M_PI*i - log((v_a*v_b)/2, 10) + 1*log(pow(n*v_a, 2)*pow(n*v_b, 2)/(pow(fabs(n), 2)*pow(fabs(n), 2)), 10)/2 - 1)/((M_PI*epsilon))
#
# SYM -> Mathematica:
# No mathematica representation found
# <lambda>() takes 1 positional argument but 2 were given
#
# SYM -> Python:
# S_ab*alpha_s*(math.pi*i - math.log((v_a*v_b)/2, 10) + 1*math.log((n*v_a)**2*(n*v_b)**2/(abs(n)**2*abs(n)**2), 10)/2 - 1)/((math.pi*epsilon))
#
# SYM -> Fortran:
#       parameter (pi = 3.1415926535897932d0)
# ...
